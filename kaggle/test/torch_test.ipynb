# %%
import torch
from tqdm import tqdm

# %%
for i in tqdm(range(10000)):
    print("alex is handsom")
# Out:
#  11%|█         | 1101/10000 [00:00<00:01, 8429.94it/s]
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# alex is handsom
# ...
